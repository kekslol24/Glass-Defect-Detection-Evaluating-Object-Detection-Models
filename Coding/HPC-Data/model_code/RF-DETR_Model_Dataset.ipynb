# %%
import os
from zipfile import ZipFile
from rfdetr import RFDETRNano

# %%
model = RFDETRNano()
# Out:
# rf-detr-nano.pth: 100%|██████████| 349M/349M [00:12<00:00, 28.6MiB/s]
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights

# %%
DATA_YAML = "data/config.yaml"
data_set_dir = "data"

# %%
path = os.getcwd()
print(path)
# Out:
# d:\Studium\5. Semester\PA2\PA2-Automated-Visual-Quality-Control-Using-Convolutional-Neural-Networks\HPC-Data\model_code

# %%
# Create the directory if it doesn't exist
extract_dir = "data"
os.makedirs(extract_dir, exist_ok=True)

# %%
with ZipFile("Glass Defect Detection.v3i.coco.zip", "r") as data_set:
    data_set.extractall(extract_dir)

# %%
model.train(dataset_dir=data_set_dir, epochs=100, batch_size=8, grad_accum_steps=2)
# Out:
# Unable to initialize TensorBoard. Logging is turned off for this session.  Run 'pip install tensorboard' to enable logging.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=3, grad_accum_steps=2, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=8, weight_decay=0.0001, epochs=100, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-nano.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=2, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='data', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=384, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=24, mask_downsample_ratio=4, tensorboard=True, wandb=False, project=None, run=None, class_names=['defect', 'glass'], run_test=True, segmentation_head=False, distributed=False)
# number of params: 30150674
# [544]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [544]
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [544]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 75
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:4316.)
# Epoch: [0]  [ 0/75]  eta: 0:28:41  lr: 0.000100  class_error: 19.71  loss: 11.3231 (11.3231)  loss_ce: 0.6348 (0.6348)  loss_bbox: 1.5860 (1.5860)  loss_giou: 1.4891 (1.4891)  loss_ce_0: 0.6117 (0.6117)  loss_bbox_0: 1.6664 (1.6664)  loss_giou_0: 1.5333 (1.5333)  loss_ce_enc: 0.6475 (0.6475)  loss_bbox_enc: 1.6132 (1.6132)  loss_giou_enc: 1.5411 (1.5411)  loss_ce_unscaled: 0.6348 (0.6348)  class_error_unscaled: 19.7115 (19.7115)  loss_bbox_unscaled: 0.3172 (0.3172)  loss_giou_unscaled: 0.7445 (0.7445)  cardinality_error_unscaled: 3714.0000 (3714.0000)  loss_ce_0_unscaled: 0.6117 (0.6117)  loss_bbox_0_unscaled: 0.3333 (0.3333)  loss_giou_0_unscaled: 0.7667 (0.7667)  cardinality_error_0_unscaled: 3705.0000 (3705.0000)  loss_ce_enc_unscaled: 0.6475 (0.6475)  loss_bbox_enc_unscaled: 0.3226 (0.3226)  loss_giou_enc_unscaled: 0.7705 (0.7705)  cardinality_error_enc_unscaled: 3840.3750 (3840.3750)  time: 22.9485  data: 20.0363  max mem: 4920
# SyntaxWarning: invalid escape sequence '\s'
# SyntaxWarning: invalid escape sequence '\s'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.train(dataset_dir=data_set_dir, epochs=100, batch_size=8, grad_accum_steps=2)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\detr.py:83, in RFDETR.train(self, **kwargs)
#      79 """
#      80 Train an RF-DETR model.
#      81 """
#      82 config = self.get_train_config(**kwargs)
# ---> 83 self.train_from_config(config, **kwargs)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\detr.py:191, in RFDETR.train_from_config(self, config, **kwargs)
#     182     early_stopping_callback = EarlyStoppingCallback(
#     183         model=self.model,
#     184         patience=config.early_stopping_patience,
#    (...)    187         segmentation_head=config.segmentation_head
#     188     )
#     189     self.callbacks["on_fit_epoch_end"].append(early_stopping_callback.update)
# --> 191 self.model.train(
#     192     **all_kwargs,
#     193     callbacks=self.callbacks,
#     194 )
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\main.py:341, in Model.train(self, callbacks, **kwargs)
#     339 model.train()
#     340 criterion.train()
# --> 341 train_stats = train_one_epoch(
#     342     model, criterion, lr_scheduler, data_loader_train, optimizer, device, epoch,
#     343     effective_batch_size, args.clip_max_norm, ema_m=self.ema_m, schedules=schedules,
#     344     num_training_steps_per_epoch=num_training_steps_per_epoch,
#     345     vit_encoder_num_layers=args.vit_encoder_num_layers, args=args, callbacks=callbacks)
#     346 train_epoch_time = time.time() - epoch_start_time
#     347 train_epoch_time_str = str(datetime.timedelta(seconds=int(train_epoch_time)))
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\engine.py:129, in train_one_epoch(model, criterion, lr_scheduler, data_loader, optimizer, device, epoch, batch_size, max_norm, ema_m, schedules, num_training_steps_per_epoch, vit_encoder_num_layers, args, callbacks)
#     126 new_targets = [{k: v.to(device) for k, v in t.items()} for t in targets[start_idx:final_idx]]
#     128 with autocast(**get_autocast_args(args)):
# --> 129     outputs = model(new_samples, new_targets)
#     130     loss_dict = criterion(outputs, new_targets)
#     131     weight_dict = criterion.weight_dict
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\models\lwdetr.py:166, in LWDETR.forward(self, samples, targets)
#     163     refpoint_embed_weight = self.refpoint_embed.weight[:self.num_queries]
#     164     query_feat_weight = self.query_feat.weight[:self.num_queries]
# --> 166 hs, ref_unsigmoid, hs_enc, ref_enc = self.transformer(
#     167     srcs, masks, poss, refpoint_embed_weight, query_feat_weight)
#     169 if hs is not None:
#     170     if self.bbox_reparam:
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\models\transformer.py:288, in Transformer.forward(self, srcs, masks, pos_embeds, refpoint_embed, query_feat)
#     283             refpoint_embed_ts_subset = refpoint_embed_ts_subset + refpoint_embed_ts
#     285         refpoint_embed = torch.concat(
#     286             [refpoint_embed_ts_subset, refpoint_embed_subset], dim=-2)
# --> 288     hs, references = self.decoder(tgt, memory, memory_key_padding_mask=mask_flatten,
#     289                     pos=lvl_pos_embed_flatten, refpoints_unsigmoid=refpoint_embed,
#     290                     level_start_index=level_start_index,
#     291                     spatial_shapes=spatial_shapes,
#     292                     valid_ratios=valid_ratios.to(memory.dtype) if valid_ratios is not None else valid_ratios)
#     293 else:
#     294     assert self.two_stage, "if not using decoder, two_stage must be True"
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\models\transformer.py:394, in TransformerDecoder.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, pos, refpoints_unsigmoid, level_start_index, spatial_shapes, valid_ratios)
#     390 pos_transformation = 1
#     392 query_pos = query_pos * pos_transformation
# --> 394 output = layer(output, memory, tgt_mask=tgt_mask,
#     395                memory_mask=memory_mask,
#     396                tgt_key_padding_mask=tgt_key_padding_mask,
#     397                memory_key_padding_mask=memory_key_padding_mask,
#     398                pos=pos, query_pos=query_pos, query_sine_embed=query_sine_embed,
#     399                is_first=(layer_id == 0),
#     400                reference_points=refpoints_input,
#     401                spatial_shapes=spatial_shapes,
#     402                level_start_index=level_start_index)
#     404 if not self.lite_refpoint_refine:
#     405     # box iterative update
#     406     new_refpoints_delta = self.bbox_embed(output)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\models\transformer.py:547, in TransformerDecoderLayer.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, pos, query_pos, query_sine_embed, is_first, reference_points, spatial_shapes, level_start_index)
#     535 def forward(self, tgt, memory,
#     536             tgt_mask: Optional[Tensor] = None,
#     537             memory_mask: Optional[Tensor] = None,
#    (...)    545             spatial_shapes=None,
#     546             level_start_index=None):
# --> 547     return self.forward_post(tgt, memory, tgt_mask, memory_mask,
#     548                              tgt_key_padding_mask, memory_key_padding_mask, pos, query_pos,
#     549                              query_sine_embed, is_first,
#     550                              reference_points, spatial_shapes, level_start_index)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\models\transformer.py:518, in TransformerDecoderLayer.forward_post(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, pos, query_pos, query_sine_embed, is_first, reference_points, spatial_shapes, level_start_index)
#     515 tgt = self.norm1(tgt)
#     517 # ========== Begin of Cross-Attention =============
# --> 518 tgt2 = self.cross_attn(
#     519     self.with_pos_embed(tgt, query_pos),
#     520     reference_points,
#     521     memory,
#     522     spatial_shapes,
#     523     level_start_index,
#     524     memory_key_padding_mask
#     525 )
#     526 # ========== End of Cross-Attention =============
#     528 tgt = tgt + self.dropout2(tgt2)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\rfdetr\models\ops\modules\ms_deform_attn.py:116, in MSDeformAttn.forward(self, query, reference_points, input_flatten, input_spatial_shapes, input_level_start_index, input_padding_mask)
#     113 N, Len_in, _ = input_flatten.shape
#     114 assert (input_spatial_shapes[:, 0] * input_spatial_shapes[:, 1]).sum() == Len_in
# --> 116 value = self.value_proj(input_flatten)
#     117 if input_padding_mask is not None:
#     118     value = value.masked_fill(input_padding_mask[..., None], float(0))
#
# File d:\Studium\5. Semester\venv\Lib\site-packages\torch\nn\modules\module.py:1927, in Module.__getattr__(self, name)
#    1922         self._backward_pre_hooks = OrderedDict()
#    1924 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1925 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1926 # https://github.com/pytorch/pytorch/pull/115074
# -> 1927 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1928     if "_parameters" in self.__dict__:
#    1929         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:
