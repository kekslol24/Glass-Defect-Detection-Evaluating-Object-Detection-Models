# %% [markdown]
# YOLO-Kaggle Results

# %%
yolo_kaggle_val = {
    "kaggle/precision": 0.96,
    'kaggle/recall': 1.0,
    'kaggle/mAP50': 0.995,
    'kaggle/mAP50-95': 0.7836242857007064
 }

# %% [markdown]
# RF-DETR-Kaggle Results

# %%
rfdetr_kaggle_val = {
    "rf-detr/precision": 1.0,
    "rf-detr/recall": 1,
    "rf-detr/mAP50": 1.0,
    "rf-detr/mAP50-95": 0.77
}

# %%
### Plot the results
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Daten in eine vergleichbare Struktur bringen
metrics = ["Precision",'Recall', 'mAP@50', 'mAP@[50:95]']
yolo_values = [yolo_kaggle_val["kaggle/precision"], yolo_kaggle_val['kaggle/recall'], yolo_kaggle_val['kaggle/mAP50'], yolo_kaggle_val['kaggle/mAP50-95']]
rfdetr_values = [rfdetr_kaggle_val["rf-detr/precision"], rfdetr_kaggle_val['rf-detr/recall'], rfdetr_kaggle_val['rf-detr/mAP50'], rfdetr_kaggle_val['rf-detr/mAP50-95']]

# 2. DataFrame für Matplotlib erstellen
data = {
    'Metric': metrics * 2,
    'Model': ['YOLO'] * len(metrics) + ['RF-DETR'] * len(metrics),
    'Value': yolo_values + rfdetr_values
}
df = pd.DataFrame(data)

# Werte für die Gruppierung vorbereiten
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.35
index = np.arange(len(metrics))

# Daten für die Modelle filtern
df_yolo = df[df['Model'] == 'YOLO']
df_rfdetr = df[df['Model'] == 'RF-DETR']

# Balken für YOLO plotten (links in der Gruppe)
bar1 = ax.bar(index, df_yolo['Value'], bar_width, label='YOLO (Kaggle)', color='#36A2EB')

# Balken für RF-DETR plotten (rechts in der Gruppe)
bar2 = ax.bar(index + bar_width, df_rfdetr['Value'], bar_width, label='RF-DETR (Kaggle)', color='#FF6384')

# 3. Diagramm formatieren
ax.set_xlabel('Evaluation Metric', fontsize=12)
ax.set_ylabel('Value', fontsize=12)
ax.set_title('Metrics comparison (YOLO vs. RF-DETR)', fontsize=14)
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(metrics)
ax.set_ylim(0, 1.05) # Y-Achse von 0 bis 1.05
ax.legend(loc='lower right')
ax.grid(axis='y', linestyle='--', alpha=0.6)

# 4. Werte auf die Balken schreiben
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 Punkte vertikaler Versatz
                    textcoords="offset points",
                    ha='center', va='bottom',
                    fontsize=9)

add_labels(bar1)
add_labels(bar2)

plt.tight_layout()
plt.show()

# %% [markdown]
# Yolo-Roboflow Results

# %%
yolo_roboflow = {'metrics/precision(B)': 0.8690170239277916,
 'metrics/recall(B)': 0.7990901674101504,
 'metrics/mAP50(B)': 0.8396457530558581,
 'metrics/mAP50-95(B)': 0.5897596903283091,
 'fitness': 0.5897596903283091}
